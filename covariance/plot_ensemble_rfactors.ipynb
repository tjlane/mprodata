# %%
import pandas as pd

# %%
ensemble_rvalue_data = [
    {
        "dataset": "l1p22_13_001_003",
        "single Rwork": 0.1791,
        "single Rfree": 0.2058,
        "ensemble Rwork": 0.1577,
        "ensemble Rfree": 0.2075,
        
    },
    {
        "dataset": "MPro_2321_3_001_003",
        "single Rwork": 0.1955,
        "single Rfree": 0.2342,
        "ensemble Rwork": 0.1693,
        "ensemble Rfree": 0.2250,
        
    },
    {
        "dataset": "MPro_6278_1_001_003",
        "single Rwork": 0.1997,
        "single Rfree": 0.2378,
        "ensemble Rwork": 0.1566,
        "ensemble Rfree": 0.2126,
        
    },
    {
        "dataset": "MPro_6439_2_001_003",
        "single Rwork": 0.1870,
        "single Rfree": 0.2173,
        "ensemble Rwork": 0.1627,
        "ensemble Rfree": 0.2174,
        
    },
]

# %%
df = pd.DataFrame(ensemble_rvalue_data)
df.to_csv("ensemble_rfactors.csv", index=False)
